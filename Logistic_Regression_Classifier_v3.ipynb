# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonimerMelo/Machine_Learning/blob/Logistic-Regression/Logistic_Regression_Classifier_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Logistic Regression
#
# Importando as bibliotecas

# %%
import numpy as np
# detalhes da função LogisticRegression podem ser acessados em [1]
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %% [markdown]
# Função que plota a região limite entre as classes preditas no modelo

# %%
def plot_classifier(classifier, X, y):
    # define ranges to plot the figure
    x_min, x_max = min(X[:, 0]) - 1.0, max(X[:, 0]) + 1.0
    y_min, y_max = min(X[:, 1]) - 1.0, max(X[:, 1]) + 1.0

    # denotes the step size that will be used in the mesh grid
    step_size = 0.01

    # define the mesh grid
    x_values, y_values = np.meshgrid(np.arange(x_min, x_max, step_size), np.arange(y_min, y_max, step_size))

    # compute the classifier output
    mesh_output = classifier.predict(np.c_[x_values.ravel(), y_values.ravel()])

    # reshape the array
    mesh_output = mesh_output.reshape(x_values.shape)

    # Plot the output using a colored plot
    plt.figure()

    # choose a color scheme you can find all the options
    # here: http://matplotlib.org/examples/color/colormaps_reference.html
    plt.pcolormesh(x_values, y_values, mesh_output, cmap=plt.cm.gray)

    # Overlay the training points on the plot
    plt.scatter(X[:, 0], X[:, 1], c=y, s=80, edgecolors='black', linewidth=1, cmap=plt.cm.Paired)

    # specify the boundaries of the figure
    plt.xlim(x_values.min(), x_values.max())
    plt.ylim(y_values.min(), y_values.max())

    # specify the ticks on the X and Y axes
    plt.xticks((np.arange(int(min(X[:, 0])-1), int(max(X[:, 0])+1), 1.0)))
    plt.yticks((np.arange(int(min(X[:, 1])-1), int(max(X[:, 1])+1), 1.0)))

    plt.show()

# %% [markdown]
# Teste inicial com um banco de dados simples

# %%
# input data
X = np.array([[4, 7], [3.5, 8], [3.1, 6.2], [0.5, 1], [1, 2], [1.2, 1.9], [6, 2], [5.7, 1.5], [5.4, 2.2]])
y = np.array([0, 0, 0, 1, 1, 1, 2, 2, 2])

# initialize the logistic regression classifier --> maiores detalhes consultar [1]
#classifier = LogisticRegression(solver='liblinear', C=100)
classifier = LogisticRegression()

# train the classifier
classifier.fit(X, y)

# draw datapoints and boundaries
plot_classifier(classifier, X, y)

# %% [markdown]
# Criando um banco de dados mais completo

# %%
from sklearn.datasets import make_blobs
X2, y2 = make_blobs(n_samples=400, n_features=2, centers=2, cluster_std=0.8, shuffle=True, random_state=0)

# %%
X2.shape
# Out:
# (400, 2)

# %%
from collections import Counter
print('Class total amount:', Counter(y2))
# Out:
# Class total amount: Counter({1: 200, 0: 200})

# %% [markdown]
# Separando o banco de dados com 70% para treino e 30% para testes

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X2, y2, test_size=0.3, random_state=0)
print('Treinamento: X_train =', X_train.shape)
print('Testes: X_test =', X_test.shape)
# Out:
# Treinamento: X_train = (280, 2)
# Testes: X_test = (120, 2)

# %% [markdown]
# Plotando o banco de dados de treinamento

# %%
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, s=50, alpha=0.6)
plt.show()

# %% [markdown]
# Treinando o Classificador com o banco de dados de treinamento e observando a região limite entre as classes preditas no modelo

# %%
# initialize the logistic regression classifier
classifier2 = LogisticRegression()

# train the classifier
classifier2.fit(X_train, y_train)

# draw datapoints and boundaries
plot_classifier(classifier2, X_train, y_train)

# %% [markdown]
# Medindo a acuráricia do modelo no banco de trainamento

# %%
classifier2.score(X_train,y_train)
# Out:
# 0.9892857142857143

# %% [markdown]
# Vamos agora predizer novos valores de `y` para o banco de dados de testes.

# %%
y_pred = classifier2.predict(X_test)

# %% [markdown]
# Plotando o banco de dados de testes com os valores das classes preditas no modelo (`y_pred`)

# %%
#plt.figure(figsize=(8,6))
plt.scatter(X_test[:,0], X_test[:,1], c=y_pred, s=50, alpha=0.6)
plt.show()

# %% [markdown]
# Quais foram as predições erradas?

# %%
err=X_test[y_test!=y_pred]
err
# Out:
# array([[1.29550716, 2.08571312]])

# %% [markdown]
# Plotando em vermelho as predições erradas feitas no banco de dados de testes

# %%
plt.scatter(X_test[:,0], X_test[:,1], c=y_pred, s=50, alpha=0.6)
plt.scatter(err[:,0], err[:,1], s=70, alpha=0.9, c='red')
plt.title('Predições erradas (em vermelho)')
plt.show()

# outra maneira de se plotar o mesmo
#plt.scatter(X_test[:,0][y_test!=y_pred], X_test[:,1][y_test!=y_pred], s=70, c='red')
#plt.scatter(X_test[:,0][y_test==y_pred], X_test[:,1][y_test==y_pred], c=y_test[y_test==y_pred], s=50, alpha=0.6)
#plt.show()

# %% [markdown]
# Medindo a acurácia do modelo no banco de testes

# %%
classifier2.score(X_test,y_test)
# Out:
# 0.9916666666666667

# %% [markdown]
# Outra maneira de medir a acurácia, utilizando `sklearn.metrics`

# %%
from sklearn.metrics import accuracy_score
result = accuracy_score(y_test,y_pred)
print("Accuracy:",result)
# Out:
# Accuracy: 0.9916666666666667

# %% [markdown]
# # Exercícios
#
# 1. Modificar `make_blobs` para gerar 3 classes e depois 4 classe e verificar a acurário do algoritmo no treinamento e no teste.
# 2. Modificar a porcentagem do banco de teste para 10% e 20% e comparar os resultados.
# 3. Utilizar a função `make_moons` de `sklearn.datasets` para gerar um banco de dados (n_samples=200, noise=0.4).
# 4. Utilizar a técnica de regressão logística para classificação.
# 5. Verificar a acurácia dessa técnica para esse banco de dados.
# 6. Modificar `n_samples=400` e `noise=0.3` na função `make_moons` e testar novamente, comparando os resultados.
# 7. Otimizar a sintonia dos hiperparâmetros `tol` e `max_iter` da função `LogisticRegression()` para tentar encontrar a melhor acurácia possível para os casos testados acima. Comentar os resultados.
# 8. Pesquisar uma forma de plotar a função perda (loss funcion) utilizando alguma função do sklearn.
# 1. Baixe o banco de dados *Students Performance Dataset* (https://www.kaggle.com/datasets/rabieelkharoua/students-performance-dataset?resource=download). Explique o significado das colunas (`features`) e as classes (`target`). Utilize o `pandas` para visualizar o banco de dados.
# 1. Verifique a necessidade de normalização dos dados. Separe o banco de dados com 70% para treinamento. Utilize *Logistic Regression Classifier* para o treinamento e teste.
# 1. Utilize o algoritmo *Random Forest* para verificar quais `features` são mais relevantes.
# 1. Utilize métricas para testas a eficiência do algoritmo.
# 1. Treine o banco de dados com o algoritmo *Random Forest* e compare os resultados.
# 1. Plote os gráficos relevantes para visualização dos resultados.

# %% [markdown]
# ##Referências
# [1] https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# [2] https://towardsdatascience.com/logistic-regression-using-python-sklearn-numpy-mnist-handwriting-recognition-matplotlib-a6b31e2b166a
#
# [3] https://www.datacamp.com/tutorial/understanding-logistic-regression-python
#
# [4] https://scikit-learn.org/stable/modules/linear_model.html
